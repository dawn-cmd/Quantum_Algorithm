# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(3)
qc.x(0)

qc.draw("mpl")

# %%
qc = QuantumCircuit(3)
qc.h(0)
qc.cx(0, 1)
qc.x(2)
qc.measure_all()
qc.draw("mpl")

# %%
from qiskit.primitives import Sampler
from qiskit.visualization import plot_histogram
results = Sampler().run(qc, shot=100).result()
statistics = results.quasi_dists[0].binary_probabilities()
display(plot_histogram(statistics))

# %%
from qiskit.circuit.library import TwoLocal
from math import pi

reference_circuit = TwoLocal(2, "rx", "cz", entanglement="linear", reps=1)
theta_list = [pi / 2, pi / 3, pi / 3, pi / 2]

reference_circuit = reference_circuit.assign_parameters(theta_list)
reference_circuit.measure_all()
reference_circuit.decompose().draw("mpl")

# %%
results = Sampler().run(reference_circuit, shot=100).result()
statistics = results.quasi_dists[0].binary_probabilities()
display(plot_histogram(statistics))

# %%
from qiskit.circuit.library import ZZFeatureMap

data = [0.6, 0.5]

zz_feature_map_reference = ZZFeatureMap(feature_dimension=2, reps=2)
zz_feature_map_reference = zz_feature_map_reference.assign_parameters(data)
zz_feature_map_reference.measure_all()
zz_feature_map_reference.decompose().draw("mpl")

# %%
results = Sampler().run(zz_feature_map_reference, shot=100).result()
statistics = results.quasi_dists[0].binary_probabilities()
display(plot_histogram(statistics))
